# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Titanic.csv')

# %%
df.sample(10)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 380         380         1       1  female  42.0      0      0  227.5250
# 224         224         1       1    male  38.0      1      0   90.0000
# 716         716         1       1  female  38.0      0      0  227.5250
# 412         412         1       1  female  33.0      1      0   90.0000
# 521         521         0       3    male  22.0      0      0    7.8958
# 357         357         0       2  female  38.0      0      0   13.0000
# 762         762         1       3    male  20.0      0      0    7.2292
# 182         182         0       3    male   9.0      4      2   31.3875
# 498         498         0       1  female  25.0      1      2  151.5500
# 448         448         1       3  female   5.0      2      1   19.2583
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 380        C   First  woman       False  NaN    Cherbourg   yes   True
# 224        S   First    man        True    C  Southampton   yes  False
# 716        C   First  woman       False    C    Cherbourg   yes   True
# 412        Q   First  woman       False    C   Queenstown   yes  False
# 521        S   Third    man        True  NaN  Southampton    no   True
# 357        S  Second  woman       False  NaN  Southampton    no   True
# 762        C   Third    man        True  NaN    Cherbourg   yes   True
# 182        S   Third  child       False  NaN  Southampton    no  False
# 498        S   First  woman       False    C  Southampton    no  False
# 448        C   Third  child       False  NaN    Cherbourg   yes  False
